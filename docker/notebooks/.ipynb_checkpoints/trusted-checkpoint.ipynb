# %%
S.<y> = PolynomialRing(QQ)
# d = 14
# (y^d + 4*y + 4).galois_group().order() == factorial(d)
# all((y^(2*m) + 4*y + 4).is_irreducible() for m in range(2, 200)) 
NumberField(y^48 - 3*y + 1, "a").discriminant().factor()
# Out:
# -1 * 3^48 * 37 * 43^2 * 1472021 * 17318016959 * 542583170819711162229637 * 4098096702468498316969714528844413
