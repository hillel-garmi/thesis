# %%
F = GF(8589935363)

# %%
F(1660697205)/F(14)
# Out:
# 6867856157

# %%
F(8487632028)/F(25)
# Out:
# 6867856157

# %%
F(6324669601)  / F(8569725934)
# Out:
# 136673628

# %%
F(573429127)^((8589935363-1)/2)+1
# Out:
# 0
