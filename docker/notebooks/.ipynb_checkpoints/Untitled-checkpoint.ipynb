# %%
A = matrix(QQ[I], [[I, 2*I - 2, 3*I - 4, 3*I - 4],[3*I, 7*I - 5, 11*I - 12, 11*I - 10]])

# %%
A.rref()
# Out:
# [    1     0     3    -1]
# [    0     1 I + 1     2]

# %%
R.<t> = QQ['t']
B = matrix()
